# %%
from ngsolve import *
from netgen.occ import *

# 1. 创建一维网格
geo = Segment((0,0,0),(1,0,0))
# help(geo)
mesh = Mesh(OCCGeometry(geo, dim=2).GenerateMesh(maxh=0.3))
fmesh = Mesh(OCCGeometry(geo, dim=1).GenerateMesh(maxh=0.3))
help(fmesh)
bds = fmesh.GetBoundaries()
print(bds)
# Out:
# Help on Mesh in module ngsolve.comp object:
#
# class Mesh(pybind11_builtins.pybind11_object)
#  |  NGSolve interface to the Netgen mesh. Provides access and functionality
#  |  to use the mesh for finite element calculations.
#  |
#  |  Parameters:
#  |
#  |  mesh (netgen.Mesh): a mesh generated from Netgen
#  |
#  |  Method resolution order:
#  |      Mesh
#  |      pybind11_builtins.pybind11_object
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  BBBoundaries(...)
#  |      BBBoundaries(self: ngsolve.comp.Mesh, pattern: str) -> ngsolve.comp.Region
#  |
#  |      Return co dim 3 boundary mesh-region matching the given regex pattern
#  |
#  |  BBoundaries(...)
#  |      BBoundaries(self: ngsolve.comp.Mesh, pattern: str) -> ngsolve.comp.Region
#  |
#  |      Return co dim 2 boundary mesh-region matching the given regex pattern
#  |
#  |  Boundaries(...)
#  |      Boundaries(*args, **kwargs)
#  |      Overloaded function.
#  |
#  |      1. Boundaries(self: ngsolve.comp.Mesh, pattern: str) -> ngsolve.comp.Region
#  |
#  |      Return boundary mesh-region matching the given regex pattern
#  |
#  |      2. Boundaries(self: ngsolve.comp.Mesh, bnds: list[int]) -> ngsolve.comp.Region
#  |
#  |      Generate boundary mesh-region by boundary condition numbers
#  |
#  |  BoundaryCF(...)
#  |      BoundaryCF(self: ngsolve.comp.Mesh, values: dict, default: ngsolve.fem.CoefficientFunction = None) -> ngsolve.fem.CoefficientFunction
#  |
#  |      Boundary wise CoefficientFunction.
#  |      First argument is a dict from either boundary names or Region objects to
#  |      CoefficientFunction (-values). Later given names/regions override earlier
#  |      values. Optional last argument (default) is the value for not given boundaries.
#  |      >>> penalty = mesh.BoundaryCF({ "top" : 1e6 }, default=0)
#  |      will create a CF being 1e6 on the top boundary and 0. elsewhere.
#  |
#  |  BuildRefinementTree(...)
#  |      BuildRefinementTree(self: ngsolve.comp.Mesh) -> pyngcore.pyngcore.Array_S_S
#  |
#  |  Contains(...)
#  |      Contains(self: ngsolve.comp.Mesh, x: float = 0.0, y: float = 0.0, z: float = 0.0) -> bool
#  |
#  |      Check if the point (x,y,z) is in the meshed domain (is inside a volume element)
#  |
#  |  Curve(...)
#  |      Curve(self: ngsolve.comp.Mesh, order: int) -> ngsolve.comp.Mesh
#  |
#  |      Curve the mesh elements for geometry approximation of given order
#  |
#  |  Elements(...)
#  |      Elements(self: ngsolve.comp.Mesh, VOL_or_BND: ngsolve.comp.VorB = <VorB.VOL: 0>) -> ngcomp::ElementRange
#  |
#  |      Return an iterator over elements on VOL/BND
#  |
#  |  GeoParamCF(...)
#  |      GeoParamCF(self: ngsolve.comp.Mesh) -> ngsolve.fem.CoefficientFunction
#  |
#  |  GetBBBoundaries(...)
#  |      GetBBBoundaries(self: ngsolve.comp.Mesh) -> tuple
#  |
#  |      Return list of boundary conditions for co dimension 3
#  |
#  |  GetBBoundaries(...)
#  |      GetBBoundaries(self: ngsolve.comp.Mesh) -> tuple
#  |
#  |      Return list of boundary conditions for co dimension 2
#  |
#  |  GetBoundaries(...)
#  |      GetBoundaries(self: ngsolve.comp.Mesh) -> tuple
#  |
#  |      Return list of boundary condition names
#  |
#  |  GetCurveOrder(...)
#  |      GetCurveOrder(self: ngsolve.comp.Mesh) -> int
#  |
#  |  GetHPElementLevel(...)
#  |      GetHPElementLevel(self: ngsolve.comp.Mesh, ei: ngsolve.comp.ElementId) -> int
#  |
#  |      THIS FUNCTION IS WIP!
#  |       Return HP-refinement level of element
#  |
#  |  GetMaterials(...)
#  |      GetMaterials(self: ngsolve.comp.Mesh) -> tuple
#  |
#  |      Return list of material names
#  |
#  |  GetNE(...)
#  |      GetNE(self: ngsolve.comp.Mesh, arg0: ngsolve.comp.VorB) -> int
#  |
#  |      Return number of elements of codimension VorB.
#  |
#  |  GetPMLTrafo(...)
#  |      GetPMLTrafo(self: ngsolve.comp.Mesh, dom: int = 1) -> ngsolve.comp.pml.PML
#  |
#  |      Return pml transformation on domain dom
#  |
#  |  GetPMLTrafos(...)
#  |      GetPMLTrafos(self: ngsolve.comp.Mesh) -> list
#  |
#  |      Return list of pml transformations
#  |
#  |  GetParentElement(...)
#  |      GetParentElement(self: ngsolve.comp.Mesh, ei: ngsolve.comp.ElementId) -> ngsolve.comp.ElementId
#  |
#  |      Return parent element id on refined mesh
#  |
#  |  GetParentFaces(...)
#  |      GetParentFaces(self: ngsolve.comp.Mesh, fnum: int) -> tuple
#  |
#  |      Return parent faces
#  |
#  |  GetParentVertices(...)
#  |      GetParentVertices(self: ngsolve.comp.Mesh, vnum: int) -> tuple
#  |
#  |      Return parent vertex numbers on refined mesh
#  |
#  |  GetPeriodicNodePairs(...)
#  |      GetPeriodicNodePairs(self: ngsolve.comp.Mesh, arg0: ngsolve.fem.NODE_TYPE) -> list
#  |
#  |      returns list of periodic nodes with their identification number as [((master_nr, minion_nr),idnr),...]
#  |
#  |  GetTrafo(...)
#  |      GetTrafo(self: ngsolve.comp.Mesh, eid: ngsolve.comp.ElementId) -> ngsolve.fem.ElementTransformation
#  |
#  |      returns element transformation of given element id
#  |
#  |  LocalHCF(...)
#  |      LocalHCF(self: ngsolve.comp.Mesh) -> ngsolve.fem.CoefficientFunction
#  |
#  |  MapToAllElements(...)
#  |      MapToAllElements(*args, **kwargs)
#  |      Overloaded function.
#  |
#  |      1. MapToAllElements(self: ngsolve.comp.Mesh, arg0: ngsolve.fem.IntegrationRule, arg1: Union[ngsolve.comp.VorB, ngsolve.comp.Region]) -> numpy.ndarray[ngsolve.fem.MeshPoint]
#  |
#  |      2. MapToAllElements(self: ngsolve.comp.Mesh, arg0: dict[ngsolve.fem.ET, ngsolve.fem.IntegrationRule], arg1: Union[ngsolve.comp.VorB, ngsolve.comp.Region]) -> numpy.ndarray[ngsolve.fem.MeshPoint]
#  |
#  |  MaterialCF(...)
#  |      MaterialCF(self: ngsolve.comp.Mesh, values: dict, default: ngsolve.fem.CoefficientFunction = None) -> ngsolve.fem.CoefficientFunction
#  |
#  |      Domain wise CoefficientFunction.
#  |      First argument is a dict from either material names or Region objects to
#  |      CoefficientFunction (-values). Later given names/regions override earlier
#  |      values. Optional last argument (default) is the value for not given materials.
#  |      >>> sigma = mesh.MaterialCF({ "steel_.*" : 2e6 }, default=0)
#  |      will create a CF being 2e6 on all domains starting with 'steel_' and 0 elsewhere.
#  |
#  |  Materials(...)
#  |      Materials(*args, **kwargs)
#  |      Overloaded function.
#  |
#  |      1. Materials(self: ngsolve.comp.Mesh, pattern: str) -> ngsolve.comp.Region
#  |
#  |      Return mesh-region matching the given regex pattern
#  |
#  |      2. Materials(self: ngsolve.comp.Mesh, domains: list[int]) -> ngsolve.comp.Region
#  |
#  |      Generate mesh-region by domain numbers
#  |
#  |  Refine(...)
#  |      Refine(self: ngsolve.comp.Mesh, mark_surface_elements: bool = False, onlyonce: bool = False) -> None
#  |
#  |      Local mesh refinement based on marked elements, uses element-bisection algorithm
#  |
#  |  RefineFromTree(...)
#  |      RefineFromTree(self: ngsolve.comp.Mesh, arg0: pyngcore.pyngcore.Array_S_S) -> None
#  |
#  |  RefineHP(...)
#  |      RefineHP(self: ngsolve.comp.Mesh, levels: int, factor: float = 0.125) -> None
#  |
#  |      Geometric mesh refinement towards marked vertices and edges, uses factor for placement of new points
#  |
#  |  Region(...)
#  |      Region(self: ngsolve.comp.Mesh, vb: ngsolve.comp.VorB, pattern: Optional[str] = '.*') -> ngsolve.comp.Region
#  |
#  |      Return boundary mesh-region matching the given regex pattern
#  |
#  |  RegionCF(...)
#  |      RegionCF(self: ngsolve.comp.Mesh, VorB: ngsolve.comp.VorB, value: dict, default: ngsolve.fem.CoefficientFunction = None) -> ngsolve.fem.CoefficientFunction
#  |
#  |      Region wise CoefficientFunction.
#  |      First argument is VorB, defining the co-dimension,
#  |      second argument is a dict from either region names or Region objects to
#  |      CoefficientFunction (-values). Later given names/regions override earlier
#  |      values. Optional last argument (default) is the value for not given regions.
#  |      >>> sigma = mesh.RegionCF(VOL, { "steel_.*" : 2e6 }, default=0)
#  |      will create a CF being 2e6 on all domains starting with 'steel_' and 0 elsewhere.
#  |
#  |  SetDeformation(...)
#  |      SetDeformation(self: ngsolve.comp.Mesh, gf: ngcomp::GridFunction) -> None
#  |
#  |      Deform the mesh with the given GridFunction
#  |
#  |  SetElementOrder(...)
#  |      SetElementOrder(self: ngsolve.comp.Mesh, eid: ngsolve.comp.ElementId, order: int) -> None
#  |
#  |      For backward compatibility, not recommended to use
#  |
#  |  SetPML(...)
#  |      SetPML(self: ngsolve.comp.Mesh, pmltrafo: ngsolve.comp.pml.PML, definedon: object) -> None
#  |
#  |      Set PML transformation on domain
#  |
#  |  SetRefinementFlag(...)
#  |      SetRefinementFlag(self: ngsolve.comp.Mesh, ei: ngsolve.comp.ElementId, refine: bool) -> None
#  |
#  |      Set refinementflag for mesh-refinement
#  |
#  |  SetRefinementFlags(...)
#  |      SetRefinementFlags(self: ngsolve.comp.Mesh, refine: list[bool]) -> None
#  |
#  |      Set refinementflags for mesh-refinement
#  |
#  |  SplitElements_Alfeld(...)
#  |      SplitElements_Alfeld(self: ngsolve.comp.Mesh) -> None
#  |
#  |  UnSetPML(...)
#  |      UnSetPML(self: ngsolve.comp.Mesh, definedon: object) -> None
#  |
#  |      Unset PML transformation on domain
#  |
#  |  UnsetDeformation(...)
#  |      UnsetDeformation(self: ngsolve.comp.Mesh) -> None
#  |
#  |      Unset the deformation
#  |
#  |  __call__(...)
#  |      __call__(self: ngsolve.comp.Mesh, x: numpy.ndarray[numpy.float64] = 0.0, y: numpy.ndarray[numpy.float64] = 0.0, z: numpy.ndarray[numpy.float64] = 0.0, VOL_or_BND: ngsolve.comp.VorB = <VorB.VOL: 0>) -> object
#  |
#  |      Get a MappedIntegrationPoint in the point (x,y,z) on the matching volume (VorB=VOL, default) or surface (VorB=BND) element. BBND elements aren't supported
#  |
#  |  __eq__(...)
#  |      __eq__(self: ngsolve.comp.Mesh, mesh: ngsolve.comp.Mesh) -> bool
#  |
#  |  __getitem__(...)
#  |      __getitem__(*args, **kwargs)
#  |      Overloaded function.
#  |
#  |      1. __getitem__(self: ngsolve.comp.Mesh, arg0: ngsolve.comp.ElementId) -> ngsolve.comp.Ngs_Element
#  |
#  |      Return Ngs_Element from given ElementId
#  |
#  |      2. __getitem__(self: ngsolve.comp.Mesh, arg0: ngsolve.comp.NodeId) -> ngsolve.comp.MeshNode
#  |
#  |      Return MeshNode from given NodeId
#  |
#  |  __getstate__(...)
#  |      __getstate__(self: ngsolve.comp.Mesh) -> tuple
#  |
#  |  __init__(...)
#  |      __init__(*args, **kwargs)
#  |      Overloaded function.
#  |
#  |      1. __init__(self: ngsolve.comp.Mesh, ngmesh: netgen.libngpy._meshing.Mesh) -> None
#  |
#  |      Make an NGSolve-mesh from a Netgen-mesh
#  |
#  |      2. __init__(self: ngsolve.comp.Mesh, filename: str, comm: pyngcore.pyngcore.MPI_Comm = <pyngcore.pyngcore.MPI_Comm object at 0x74d4f8106df0>) -> None
#  |
#  |      Load a mesh from file.
#  |      In MPI-parallel mode the mesh is distributed over the MPI-group given by the communicator (WIP!)
#  |
#  |  __setstate__(...)
#  |      __setstate__(self: ngsolve.comp.Mesh, arg0: tuple) -> None
#  |
#  |  nnodes(...)
#  |      nnodes(self: ngsolve.comp.Mesh, arg0: ngsolve.fem.NODE_TYPE) -> int
#  |
#  |      number of nodes given type
#  |
#  |  nodes(...)
#  |      nodes(self: ngsolve.comp.Mesh, node_type: ngsolve.fem.NODE_TYPE) -> ngsolve.comp.MeshNodeRange
#  |
#  |      iterable of mesh nodes of type node_type
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties defined here:
#  |
#  |  comm
#  |      MPI-communicator the Mesh lives in
#  |
#  |  dim
#  |      mesh dimension
#  |
#  |  edges
#  |      iterable of mesh edges
#  |
#  |  faces
#  |      iterable of mesh faces
#  |
#  |  facets
#  |      iterable of mesh facets
#  |
#  |  levels
#  |      multigrid levels
#  |
#  |  ne
#  |      number of volume elements
#  |
#  |  nedge
#  |      number of edges
#  |
#  |  nface
#  |      number of faces
#  |
#  |  nfacet
#  |      number of facets
#  |
#  |  ngmesh
#  |      the Netgen mesh
#  |
#  |  nv
#  |      number of vertices
#  |
#  |  vertices
#  |      iterable of mesh vertices
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |
#  |  deformation
#  |      mesh deformation
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __hash__ = None
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from pybind11_builtins.pybind11_object:
#  |
#  |  __new__(*args, **kwargs) class method of pybind11_builtins.pybind11_object
#  |      Create and return a new object.  See help(type) for accurate signature.
#
# ('default', 'default')

# %%
# help(geo.end)
fmesh.ngmesh.SetBCName(0,"start")
fmesh.ngmesh.SetBCName(1,"end")
fmesh=Mesh(fmesh.ngmesh)
bds = fmesh.GetBoundaries()
print(bds)
b1 = fmesh.Boundaries('start')
print(b1)
# Out:
# ('start', 'end')
# <ngsolve.comp.Region object at 0x74d4ca480cb0>

# %%
# for i in range(fmesh.nvb):
#     point = fmesh.Point(i)
#     print(f"Vertex {i}: {point}")
fm = fmesh.ngmesh
help(fm)
# Out:
# Help on Mesh in module netgen.libngpy._meshing object:
#
# class Mesh(pybind11_builtins.pybind11_object)
#  |  Method resolution order:
#  |      Mesh
#  |      pybind11_builtins.pybind11_object
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  Add(...)
#  |      Add(*args, **kwargs)
#  |      Overloaded function.
#  |
#  |      1. Add(self: netgen.libngpy._meshing.Mesh, arg0: netgen.libngpy._meshing.MeshPoint) -> netgen.libngpy._meshing.PointId
#  |
#  |      2. Add(self: netgen.libngpy._meshing.Mesh, arg0: netgen.libngpy._meshing.Element3D) -> netgen.libngpy._meshing.ElementId3D
#  |
#  |      3. Add(self: netgen.libngpy._meshing.Mesh, arg0: netgen.libngpy._meshing.Element2D) -> netgen.libngpy._meshing.ElementId2D
#  |
#  |      4. Add(self: netgen.libngpy._meshing.Mesh, el: netgen.libngpy._meshing.Element1D, project_geominfo: bool = False) -> netgen.libngpy._meshing.ElementId1D
#  |
#  |      5. Add(self: netgen.libngpy._meshing.Mesh, arg0: netgen.libngpy._meshing.Element0D) -> int
#  |
#  |      6. Add(self: netgen.libngpy._meshing.Mesh, arg0: netgen.libngpy._meshing.FaceDescriptor) -> int
#  |
#  |  AddElements(...)
#  |      AddElements(self: netgen.libngpy._meshing.Mesh, dim: int, index: int, data: Buffer, base: int = 0, project_geometry: bool = False) -> None
#  |
#  |  AddPointIdentification(...)
#  |      AddPointIdentification(self: netgen.libngpy._meshing.Mesh, pid1: object, pid2: object, identnr: int, type: netgen.libngpy._meshing.IdentificationType = <IdentificationType.PERIODIC: 2>) -> None
#  |
#  |  AddPoints(...)
#  |      AddPoints(self: netgen.libngpy._meshing.Mesh, arg0: Buffer) -> None
#  |
#  |  AddRegion(...)
#  |      AddRegion(self: netgen.libngpy._meshing.Mesh, name: str, dim: int) -> int
#  |
#  |  AddSingularity(...)
#  |      AddSingularity(self: netgen.libngpy._meshing.Mesh, arg0: netgen.libngpy._meshing.PointId, arg1: float) -> None
#  |
#  |  BoundaryLayer(...)
#  |      BoundaryLayer(self: netgen.libngpy._meshing.Mesh, boundary: Union[str, int, list[int]], thickness: Union[float, list[float]], material: Optional[Union[str, dict[str, str]]] = None, domains: Union[str, int, list[int]] = '.*', outside: bool = False, project_boundaries: Optional[Union[str, list[int]]] = None, grow_edges: bool = True, limit_growth_vectors: bool = False, sides_keep_surfaceindex: bool = False, disable_curving: bool = True) -> None
#  |
#  |      Add boundary layer to mesh. see help(BoundaryLayerParameters) for details.
#  |
#  |  BoundaryLayer2(...)
#  |      BoundaryLayer2(self: netgen.libngpy._meshing.Mesh, domain: int, thicknesses: pyngcore.pyngcore.Array_D_S, make_new_domain: bool = True, boundaries: pyngcore.pyngcore.Array_I_S = <pyngcore.pyngcore.Array_I_S object at 0x74d4f8326af0>) -> int
#  |
#  |  BuildSearchTree(...)
#  |      BuildSearchTree(self: netgen.libngpy._meshing.Mesh, dim: int = 3) -> None
#  |
#  |  CalcElementMapping(...)
#  |      CalcElementMapping(self: netgen.libngpy._meshing.Mesh, arg0: Buffer, arg1: Buffer) -> None
#  |
#  |  CalcLocalH(...)
#  |      CalcLocalH(self: netgen.libngpy._meshing.Mesh, arg0: float, arg1: int) -> None
#  |
#  |  CalcMinMaxAngle(...)
#  |      CalcMinMaxAngle(self: netgen.libngpy._meshing.Mesh, badelement_limit: float = 175.0) -> dict
#  |
#  |  CalcTotalBadness(...)
#  |      CalcTotalBadness(self: netgen.libngpy._meshing.Mesh, arg0: netgen::MeshingParameters) -> float
#  |
#  |  Compress(...)
#  |      Compress(self: netgen.libngpy._meshing.Mesh) -> None
#  |
#  |  Coordinates(...)
#  |      Coordinates(self: netgen.libngpy._meshing.Mesh) -> numpy.ndarray
#  |
#  |  Copy(...)
#  |      Copy(self: netgen.libngpy._meshing.Mesh) -> netgen.libngpy._meshing.Mesh
#  |
#  |  Curve(...)
#  |      Curve(self: netgen.libngpy._meshing.Mesh, arg0: int) -> None
#  |
#  |  DeleteSurfaceElement(...)
#  |      DeleteSurfaceElement(self: netgen.libngpy._meshing.Mesh, arg0: netgen.libngpy._meshing.ElementId2D) -> None
#  |
#  |  Distribute(...)
#  |      Distribute(self: netgen.libngpy._meshing.Mesh, comm: pyngcore.pyngcore.MPI_Comm) -> netgen.libngpy._meshing.Mesh
#  |
#  |  Elements0D(...)
#  |      Elements0D(self: netgen.libngpy._meshing.Mesh) -> Array[netgen.libngpy._meshing.Element0D]
#  |
#  |  Elements1D(...)
#  |      Elements1D(self: netgen.libngpy._meshing.Mesh) -> netgen.libngpy._meshing.Array_N6netgen7SegmentE_N6netgen12SegmentIndexE
#  |
#  |  Elements2D(...)
#  |      Elements2D(self: netgen.libngpy._meshing.Mesh) -> netgen.libngpy._meshing.Array_N6netgen9Element2dE_N6netgen19SurfaceElementIndexE
#  |
#  |  Elements3D(...)
#  |      Elements3D(self: netgen.libngpy._meshing.Mesh) -> netgen.libngpy._meshing.Array_N6netgen7ElementE_N6netgen12ElementIndexE
#  |
#  |  EnableTable(...)
#  |      EnableTable(self: netgen.libngpy._meshing.Mesh, name: str, set: bool = True) -> None
#  |
#  |  Export(...)
#  |      Export(self: netgen.libngpy._meshing.Mesh, filename: str, format: str) -> None
#  |
#  |      Export mesh to other file format. Supported formats are:
#  |              Abaqus Format   (.mesh)
#  |              Chemnitz Format (*)
#  |              DIFFPACK Format (.mesh)
#  |              EdgeElement Format      (*)
#  |              Elmer Format    (*)
#  |              FEAP Format     (.mesh)
#  |              Fepp Format     (*)
#  |              Fluent Format   (.mesh)
#  |              Gmsh Format     (.gmsh)
#  |              Gmsh2 Format    (.gmsh2)
#  |              JCMwave Format  (.jcm)
#  |              Medit Format    (.mesh)
#  |              Neutral Format  (.mesh)
#  |              OpenFOAM 1.5+ Compressed        (*)
#  |              OpenFOAM 1.5+ Format    (*)
#  |              Permas Format   (.mesh)
#  |              STL Extended Format     (.stl, .stlb)
#  |              STL Format      (.stl, .stlb)
#  |              Surface Mesh Format     (.mesh, .surf)
#  |              TET Format      (.tet)
#  |              TecPlot Format  (.mesh)
#  |              Tochnog Format  (.mesh)
#  |              VRML Format     (.*)
#  |              VRML Format Faces       (.*)
#  |
#  |  FaceDescriptor(...)
#  |      FaceDescriptor(self: netgen.libngpy._meshing.Mesh, arg0: int) -> netgen.libngpy._meshing.FaceDescriptor
#  |
#  |  FaceDescriptors(...)
#  |      FaceDescriptors(self: netgen.libngpy._meshing.Mesh) -> Array[netgen.libngpy._meshing.FaceDescriptor]
#  |
#  |  GenerateVolumeMesh(...)
#  |      GenerateVolumeMesh(self: netgen.libngpy._meshing.Mesh, mp: netgen::MeshingParameters = None, **kwargs) -> None
#  |
#  |
#  |      Meshing Parameters
#  |      -------------------
#  |
#  |      maxh: float = 1e10
#  |        Global upper bound for mesh size.
#  |
#  |      grading: float = 0.3
#  |        Mesh grading how fast the local mesh size can change.
#  |
#  |      meshsizefilename: str = None
#  |        Load meshsize from file. Can set local mesh size for points
#  |        and along edges. File must have the format:
#  |
#  |          nr_points
#  |          x1, y1, z1, meshsize
#  |          x2, y2, z2, meshsize
#  |          ...
#  |          xn, yn, zn, meshsize
#  |
#  |          nr_edges
#  |          x11, y11, z11, x12, y12, z12, meshsize
#  |          ...
#  |          xn1, yn1, zn1, xn2, yn2, zn2, meshsize
#  |
#  |      segmentsperedge: float = 1.
#  |        Minimal number of segments per edge.
#  |
#  |      quad_dominated: bool = False
#  |        Quad-dominated surface meshing.
#  |
#  |      blockfill: bool = True
#  |        Do fast blockfilling.
#  |
#  |      filldist: float = 0.1
#  |        Block fill up to distance
#  |
#  |      delaunay: bool = True
#  |        Use delaunay meshing.
#  |
#  |      delaunay2d : bool = True
#  |        Use delaunay meshing for 2d geometries.
#  |
#  |      Optimization Parameters
#  |      -----------------------
#  |
#  |      optimize3d: str = "cmdmustm"
#  |        3d optimization strategy:
#  |          m .. move nodes
#  |          M .. move nodes, cheap functional
#  |          s .. swap faces
#  |          c .. combine elements
#  |          d .. divide elements
#  |          p .. plot, no pause
#  |          P .. plot, Pause
#  |          h .. Histogramm, no pause
#  |          H .. Histogramm, pause
#  |
#  |      optsteps3d: int = 3
#  |        Number of 3d optimization steps.
#  |
#  |      optimize2d: str = "smcmSmcmSmcm"
#  |        2d optimization strategy:
#  |          s .. swap, opt 6 lines/node
#  |          S .. swap, optimal elements
#  |          m .. move nodes
#  |          p .. plot, no pause
#  |          P .. plot, pause
#  |          c .. combine
#  |
#  |      optsteps2d: int = 3
#  |        Number of 2d optimization steps.
#  |
#  |      elsizeweight: float = 0.2
#  |        Weight of element size w.r.t. element shape in optimization.
#  |
#  |  GetBCName(...)
#  |      GetBCName(self: netgen.libngpy._meshing.Mesh, arg0: int) -> str
#  |
#  |  GetCD2Name(...)
#  |      GetCD2Name(self: netgen.libngpy._meshing.Mesh, arg0: int) -> str
#  |
#  |  GetCD3Name(...)
#  |      GetCD3Name(self: netgen.libngpy._meshing.Mesh, arg0: int) -> str
#  |
#  |  GetCurveOrder(...)
#  |      GetCurveOrder(self: netgen.libngpy._meshing.Mesh) -> int
#  |
#  |  GetGeometry(...)
#  |      GetGeometry(self: netgen.libngpy._meshing.Mesh) -> netgen.libngpy._meshing.NetgenGeometry
#  |
#  |  GetIdentifications(...)
#  |      GetIdentifications(self: netgen.libngpy._meshing.Mesh) -> list
#  |
#  |  GetLocalH(...)
#  |      GetLocalH(self: netgen.libngpy._meshing.Mesh, arg0: int) -> netgen.libngpy._meshing.LocalH
#  |
#  |  GetMaterial(...)
#  |      GetMaterial(self: netgen.libngpy._meshing.Mesh, arg0: int) -> str
#  |
#  |  GetNCD2Names(...)
#  |      GetNCD2Names(self: netgen.libngpy._meshing.Mesh) -> int
#  |
#  |  GetNDomains(...)
#  |      GetNDomains(self: netgen.libngpy._meshing.Mesh) -> int
#  |
#  |  GetNFaceDescriptors(...)
#  |      GetNFaceDescriptors(self: netgen.libngpy._meshing.Mesh) -> int
#  |
#  |  GetNrIdentifications(...)
#  |      GetNrIdentifications(self: netgen.libngpy._meshing.Mesh) -> int
#  |
#  |  GetQualityHistogram(...)
#  |      GetQualityHistogram(self: netgen.libngpy._meshing.Mesh) -> pyngcore.pyngcore.FlatArray_I_S
#  |
#  |  GetRegionNames(...)
#  |      GetRegionNames(self: netgen.libngpy._meshing.Mesh, dim: Optional[int] = None, codim: Optional[int] = None) -> list[str]
#  |
#  |  GetSubMesh(...)
#  |      GetSubMesh(self: netgen.libngpy._meshing.Mesh, domains: str = '', faces: str = '') -> netgen.libngpy._meshing.Mesh
#  |
#  |  GetVolumeNeighboursOfSurfaceElement(...)
#  |      GetVolumeNeighboursOfSurfaceElement(self: netgen.libngpy._meshing.Mesh, arg0: int) -> tuple
#  |
#  |      Returns element nrs of volume element connected to surface element, -1 if no volume element
#  |
#  |  IdentifyPeriodicBoundaries(...)
#  |      IdentifyPeriodicBoundaries(self: netgen.libngpy._meshing.Mesh, identification_name: str, face1: str, mapping: netgen.libngpy._meshing.Trafo, point_tolerance: float = -1.0) -> int
#  |
#  |  Load(...)
#  |      Load(self: netgen.libngpy._meshing.Mesh, arg0: str) -> None
#  |
#  |  MacroElementNr(...)
#  |      MacroElementNr(self: netgen.libngpy._meshing.Mesh, elnr: int, dim: Optional[int] = None) -> int
#  |
#  |      number of macro element of element number elnr
#  |
#  |  Mirror(...)
#  |      Mirror(self: netgen.libngpy._meshing.Mesh, arg0: netgen.libngpy._meshing.Point3d, arg1: netgen.libngpy._meshing.Vec3d) -> netgen.libngpy._meshing.Mesh
#  |
#  |  OptimizeMesh2d(...)
#  |      OptimizeMesh2d(self: netgen.libngpy._meshing.Mesh, mp: netgen::MeshingParameters = None, faceindex: int = 0) -> None
#  |
#  |  OptimizeVolumeMesh(...)
#  |      OptimizeVolumeMesh(self: netgen.libngpy._meshing.Mesh, mp: netgen::MeshingParameters) -> None
#  |
#  |  Partition(...)
#  |      Partition(self: netgen.libngpy._meshing.Mesh, numproc: int) -> None
#  |
#  |  Points(...)
#  |      Points(self: netgen.libngpy._meshing.Mesh) -> netgen.libngpy._meshing.Array_N6netgen9MeshPointE_N6netgen10PointIndexE
#  |
#  |  Refine(...)
#  |      Refine(self: netgen.libngpy._meshing.Mesh, adaptive: bool = False) -> None
#  |
#  |  RestrictLocalH(...)
#  |      RestrictLocalH(self: netgen.libngpy._meshing.Mesh, p: netgen.libngpy._meshing.Point3d, h: float, layer: int = 1) -> None
#  |
#  |  Save(...)
#  |      Save(self: netgen.libngpy._meshing.Mesh, arg0: os.PathLike) -> None
#  |
#  |  Scale(...)
#  |      Scale(self: netgen.libngpy._meshing.Mesh, arg0: float) -> None
#  |
#  |  SecondOrder(...)
#  |      SecondOrder(self: netgen.libngpy._meshing.Mesh) -> None
#  |
#  |  SetBCName(...)
#  |      SetBCName(self: netgen.libngpy._meshing.Mesh, arg0: int, arg1: str) -> None
#  |
#  |  SetCD2Name(...)
#  |      SetCD2Name(self: netgen.libngpy._meshing.Mesh, arg0: int, arg1: str) -> None
#  |
#  |  SetCD3Name(...)
#  |      SetCD3Name(self: netgen.libngpy._meshing.Mesh, arg0: int, arg1: str) -> None
#  |
#  |  SetGeometry(...)
#  |      SetGeometry(self: netgen.libngpy._meshing.Mesh, arg0: netgen.libngpy._meshing.NetgenGeometry) -> None
#  |
#  |  SetLocalH(...)
#  |      SetLocalH(self: netgen.libngpy._meshing.Mesh, localh: netgen.libngpy._meshing.LocalH, layer: int = 1) -> None
#  |
#  |  SetMaterial(...)
#  |      SetMaterial(self: netgen.libngpy._meshing.Mesh, arg0: int, arg1: str) -> None
#  |
#  |  SetMaxHDomain(...)
#  |      SetMaxHDomain(self: netgen.libngpy._meshing.Mesh, arg0: list) -> None
#  |
#  |  Split2Tets(...)
#  |      Split2Tets(self: netgen.libngpy._meshing.Mesh) -> None
#  |
#  |  SplitAlfeld(...)
#  |      SplitAlfeld(self: netgen.libngpy._meshing.Mesh) -> None
#  |
#  |  SplitFacesByAdjacentDomains(...)
#  |      SplitFacesByAdjacentDomains(self: netgen.libngpy._meshing.Mesh) -> None
#  |
#  |  SplitPowellSabin(...)
#  |      SplitPowellSabin(self: netgen.libngpy._meshing.Mesh) -> None
#  |
#  |  Update(...)
#  |      Update(self: netgen.libngpy._meshing.Mesh) -> None
#  |
#  |  ZRefine(...)
#  |      ZRefine(self: netgen.libngpy._meshing.Mesh, arg0: str, arg1: pyngcore.pyngcore.Array_D_S) -> None
#  |
#  |  __getitem__(...)
#  |      __getitem__(*args, **kwargs)
#  |      Overloaded function.
#  |
#  |      1. __getitem__(self: netgen.libngpy._meshing.Mesh, arg0: netgen.libngpy._meshing.PointId) -> netgen.libngpy._meshing.MeshPoint
#  |
#  |      2. __getitem__(self: netgen.libngpy._meshing.Mesh, arg0: netgen.libngpy._meshing.ElementId3D) -> netgen.libngpy._meshing.Element3D
#  |
#  |      3. __getitem__(self: netgen.libngpy._meshing.Mesh, arg0: netgen.libngpy._meshing.ElementId2D) -> netgen.libngpy._meshing.Element2D
#  |
#  |      4. __getitem__(self: netgen.libngpy._meshing.Mesh, arg0: netgen.libngpy._meshing.ElementId1D) -> netgen.libngpy._meshing.Element1D
#  |
#  |  __getstate__(...)
#  |      __getstate__(self: netgen.libngpy._meshing.Mesh) -> tuple
#  |
#  |  __init__(...)
#  |      __init__(self: netgen.libngpy._meshing.Mesh, dim: int = 3, comm: pyngcore.pyngcore.MPI_Comm = <pyngcore.pyngcore.MPI_Comm object at 0x74d4f82ffc30>) -> None
#  |
#  |  __setitem__(...)
#  |      __setitem__(self: netgen.libngpy._meshing.Mesh, arg0: netgen.libngpy._meshing.PointId, arg1: netgen.libngpy._meshing.MeshPoint) -> netgen.libngpy._meshing.MeshPoint
#  |
#  |  __setstate__(...)
#  |      __setstate__(self: netgen.libngpy._meshing.Mesh, arg0: tuple) -> None
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  EnableTableClass(...) method of builtins.PyCapsule instance
#  |      EnableTableClass(name: str, set: bool = True) -> None
#  |
#  |  Receive(...) method of builtins.PyCapsule instance
#  |      Receive(comm: pyngcore.pyngcore.MPI_Comm) -> netgen.libngpy._meshing.Mesh
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties defined here:
#  |
#  |  bounding_box
#  |
#  |  comm
#  |      MPI-communicator the Mesh lives in
#  |
#  |  macromesh
#  |      mesh before hp-refinement
#  |
#  |  ne
#  |
#  |  parentelements
#  |
#  |  parentsurfaceelements
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  dim
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from pybind11_builtins.pybind11_object:
#  |
#  |  __new__(*args, **kwargs) class method of pybind11_builtins.pybind11_object
#  |      Create and return a new object.  See help(type) for accurate signature.

# %%
# print(fm.Elements1D())
print(fm.GetGeometry())
# Out:
# <netgen.libngpy._NgOCC.OCCGeometry object at 0x74d4ca471610>

# %% [markdown]
# GetSubMesh(...)
#  |      GetSubMesh(self: netgen.libngpy._meshing.Mesh, domains: str = '', faces: str = '') -> netgen.libngpy._meshing.Mesh

# %%
Draw(mesh)
for v in mesh.vertices:
    print(v,v.point)
for el in mesh.Elements(VOL):
    print("vertices:",el.vertices)
    # print(type(el.vertices[0]))
    print("edges:",el.edges)
    # print(type(el.edges[0]))
# Out:
# V0 (0.0, 0.0)
# V1 (1.0, 0.0)
# V2 (0.3333333333333334, 0.0)
# V3 (0.6666666666666667, 0.0)

# %%
# 2. 定义有限元空间
# fes = H1(mesh, order=1, dirichlet=".*")
# fes = H1(mesh, order=1)
fes = H1(fmesh,order=1,dirichlet='start')
print(fes.ndof)
print(fes.FreeDofs())
# Out:
# 4
# 0: 0111

# %%
# 3. 定义未知函数和测试函数
u = fes.TrialFunction()
v = fes.TestFunction()

# 4. 定义右端项和双线性形式
f = CoefficientFunction(-2)  # 源项 f(x) = 2
a = BilinearForm(fes)
a += grad(u) * grad(u) * dx  # 泊松方程弱形式

# 5. 定义线性形式 (右端项)
l = LinearForm(fes)
l += f * v * dx

# 6. 应用边界条件
#    u(0)=0, u(1)=1
u_exact = x*x  # 精确解用于边界条件
with TaskManager():
    a.Assemble()
    l.Assemble()

# 7. 创建解向量并求解
gfu = GridFunction(fes)
gfu.Set(u_exact, BND)  # 设置边界条件
r = l.vec.CreateVector()
r.data = l.vec - a.mat * gfu.vec
gfu.vec.data += a.mat.Inverse(fes.FreeDofs()) * r
# Out:
# used dof inconsistency
# (silence this warning by setting BilinearForm(...check_unused=False) )

# %%
print(a.mat)
# Out:
# Row 0:   0: 0   2: 0
# Row 1:   1: 0   3: 0
# Row 2:   0: 0   2: 0   3: 0
# Row 3:   1: 0   2: 0   3: 0

# %%
print(u)
# Out:
# coef trial-function diffop = Id, real

# %%
# 8. 可视化结果
Draw(gfu, mesh, "solution")
# Draw(u_exact - gfu, mesh, "error")

# %%
error = sqrt(Integrate((gfu-u_exact)**2, fmesh))
print(error)
# Out:
# 0.44721359549995726

# %%
help(Draw)
# Out:
# Help on built-in function Draw in module ngsolve.solve:
#
# Draw(...) method of builtins.PyCapsule instance
#     Draw(*args, **kwargs)
#     Overloaded function.
#
#     1. Draw(cf: ngsolve.fem.CoefficientFunction, mesh: ngsolve.comp.Mesh, name: str, sd: int = 2, autoscale: bool = True, min: float = 0.0, max: float = 1.0, draw_vol: bool = True, draw_surf: bool = True, reset: bool = False, title: str = '', number_format: str = '%.3e', unit: str = '', **kwargs) -> None
#
#
#     Parameters:
#
#     cf : ngsolve.comp.CoefficientFunction
#       input CoefficientFunction to draw
#
#     mesh : ngsolve.comp.Mesh
#       input mesh
#
#     name : string
#       input name
#
#     sd : int
#       input subdivisions
#
#     autoscale : bool
#       input autscale
#
#     min : float
#       input minimum value. Need autoscale = false
#
#     max : float
#       input maximum value. Need autoscale = false
#
#     draw_vol : bool
#       input draw volume
#
#     draw_surf : bool
#       input draw surface
#
#     title : string
#       printed on top of colormap
#
#     number_format : string
#       printf-style format string for numbers under colormap
#
#     unit : string
#       string (ASCII only) to print after maximum value of colormap
#
#
#
#     2. Draw(gf: ngsolve.comp.GridFunction, sd: int = 2, autoscale: bool = True, min: float = 0.0, max: float = 1.0, **kwargs) -> None
#
#
#     Parameters:
#
#     gf : ngsolve.comp.GridFunction
#       input GridFunction to draw
#
#     sd : int
#       input subdivisions
#
#     autoscale : bool
#       input autscale
#
#     min : float
#       input minimum value. Need autoscale = false
#
#     max : float
#       input maximum value. Need autoscale = false
#
#
#
#     3. Draw(mesh: ngsolve.comp.Mesh, **kwargs) -> None
#
#     4. Draw(arg0: object) -> None
